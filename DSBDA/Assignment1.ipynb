# %% [markdown]
# # Assignment 1

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import data from csv file
#
# dataset - titanic dataset<br>
# link - https://www.kaggle.com/datasets/brendan45774/test-file

# %%
data = pd.read_csv("./Datasets/tested.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# ### Describing data with `describe()` method
# This shows count, mean, min, max, percentile deviations.

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %% [markdown]
# ## Get information about the data using `info()` method.
# Displays columns, columns' data type and count of non-null values in that column.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %% [markdown]
# ## Get shape of data using `.shape` property.
# returns (row_count, column_count)

# %%
data.shape
# Out:
# (418, 12)

# %% [markdown]
# ## Get total no of cells in the data using `.size` property.
# returns row_count * column_count

# %%
data.size
# Out:
# 5016

# %% [markdown]
# ## Get names of the columns in the data using `.columns` property.
# returns array of column names

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# timepass

# %%
np.array(data[data['Cabin'].notna()]['Pclass'])

# %%
X_data = data.drop(['Pclass'], axis=1)
y_data = data['Pclass']

# %% [markdown]
# ## Creating a new dataframe from dictionary

# %%
dictinary = {"Id" : data['PassengerId'].iloc[[0, 1]], "Age" : data['Age'].iloc[[0, 1]]}
df2 = pd.DataFrame(dictinary)
df2
# Out:
#     Id   Age
# 0  892  34.5
# 1  893  47.0

# %%
df3 = data.drop(0) # dropped row 0
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                      Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
df3 = data.drop(['PassengerId', 'Ticket', 'Name'], axis=1) # dropped columns
df3
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Cabin Embarked
# 0           0       3    male  34.5      0      0    7.8292   NaN        Q
# 1           1       3  female  47.0      1      0    7.0000   NaN        S
# 2           0       2    male  62.0      0      0    9.6875   NaN        Q
# 3           0       3    male  27.0      0      0    8.6625   NaN        S
# 4           1       3  female  22.0      1      1   12.2875   NaN        S
# ..        ...     ...     ...   ...    ...    ...       ...   ...      ...
# 413         0       3    male   NaN      0      0    8.0500   NaN        S
# 414         1       1  female  39.0      0      0  108.9000  C105        C
# 415         0       3    male  38.5      0      0    7.2500   NaN        S
# 416         0       3    male   NaN      0      0    8.0500   NaN        S
# 417         0       3    male   NaN      1      1   22.3583   NaN        C
#
# [418 rows x 9 columns]

# %%
data[(data['Age'] < 18) & (data['Survived'] == 0)]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 5            897         0       3               Svensson, Mr. Johan Cervin
# 21           913         0       3                Olsen, Master. Artur Karl
# 55           947         0       3                     Rice, Master. Albert
# 60           952         0       3                          Dika, Mr. Mirko
# 64           956         0       1              Ryerson, Master. John Borie
# 80           972         0       3                     Boulos, Master. Akar
# 89           981         0       2              Wells, Master. Ralph Lester
# 154         1046         0       3             Asplund, Master. Filip Oscar
# 161         1053         0       3           Touma, Master. Georges Youssef
# 187         1079         0       3                       Davies, Mr. Joseph
# 192         1084         0       3        van Billiard, Master. Walter John
# ...

# %% [markdown]
# Boys be sed ;)

# %%
data[(data['Age'] < 18) & (data['Survived'] == 1)]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 104          996         1       3  Thomas, Mrs. Alexander (Thamine Thelma")"
# 117         1009         1       3            Sandstrom, Miss. Beatrice Irene
# 120         1012         1       2                       Watt, Miss. Bertha J
# 125         1017         1       3                   Cribb, Miss. Laura Alice
# 140         1032         1       3                Goodwin, Miss. Jessie Allis
# 175         1067         1       2                  Brown, Miss. Edith Eileen
# 203         1095         1       2                 Quick, Miss. Winifred Vera
# 250         1142         1       2                      West, Miss. Barbara J
# 263         1155         1       3               Klasen, Miss. Gertrud Emilia
# 283         1175         1       3                 Touma, Miss. Maria Youssef
# 284         1176         1       3                Rosblom, Miss. Salli Helena
# ...

# %%
data['Cabin'].iloc[[0]] == None
# Out:
# 0    False
# Name: Cabin, dtype: bool

# %%
data[data['Age'] < 18]['SurvivalRate'].mean()
# Out:
# 60.146341463414636

# %%
def convert(sr):
    return sr / 100

data['SurvivalRate'] = data['SurvivalRate'].apply(convert)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data['Sex_int'] = data['Sex'].map({"male" : 0, "female" : 1})
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# ## Calculating Survival Probability.

# %%
y, X = np.unique(data[data['Survived'] == 1]['Pclass'], return_counts = True)

# %% [markdown]
# ## Displaying bar plot of survival rate.

# %%
plt.bar(y, X)
plt.xticks([1, 2, 3])
plt.xlabel("Person Class")
plt.ylabel("Survival Rate")
# Out:
# Text(0, 0.5, 'Survival Rate')

# %%
X
# Out:
# array([50, 30, 72], dtype=int64)
